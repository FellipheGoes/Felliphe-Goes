# %%
import scipy as sp
import numpy as np
from scipy.integrate import odeint
from matplotlib import use
use('nbagg')
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
import scipy.linalg as la

# %%
def func (x, t,omega):
    I=10
    Ip=1
    K1=50000
    K2=50000
    gama=1
    F=sp.transpose(sp.array([0,((I-Ip)/I)*gama*omega**2*(sp.cos(omega*t)), 0 ,((I-Ip)/I)*gama*omega**2*(sp.sin(omega*t))]))
    A=sp.array([[0, 1, 0, 0],
               [-K1/I, 0, 0, -Ip*omega/I],
               [0, 0, 0, 1],
               [0,Ip*omega/I, -K2/I, 0]])
    
    a1,a2,b1,b2=x
    dxdt=A @ x + F
    return dxdt

# %%
z0=[0,0,0,0]
n=10000
t=sp.linspace(0,10,n)

# %%
def calc(omega):
    sol=odeint(func, z0,t,args=(omega,))
    FFt=np.absolute(np.fft.fft(sol[:, 0]))
    plt.plot( FFt[0:n/2])
    plt.show()
    plt.figure()
    plt.plot( t, sol[:,0])
    plt.show()
    plt.figure()

# %%
interact(calc, omega=(0, 100, 10))
# Out:
# C:\Users\felli_000\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
C=sp.array([[0, 1, 0, 0],
               [1, 0, 0, 1],
               [0, 0, 0, 1],
               [0,3, 4, 0]])

# %%
D=sp.transpose([1,1,1,1])

# %%
C+D
# Out:
# array([[1, 2, 1, 1],
#        [2, 1, 1, 2],
#        [1, 1, 1, 2],
#        [1, 4, 5, 1]])
